# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/Python_8_Operations_in_pandas/blob/main/8_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Объявите функцию series_index, которая принимает на вход два списка:
# с данными и индексами. В итоге создает из них Series и возвращает его.


import pandas as pd
def series_index(data, indexes):
    C = pd.Series(data = data, index = indexes)
    return C
