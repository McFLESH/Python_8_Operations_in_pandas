# %% [markdown]
# <a href="https://colab.research.google.com/github/McFLESH/Python_8_Operations_in_pandas/blob/main/8_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Объявите функцию data_shape, которая принимает на вход строку - название csv-файла, а возвращает размер этого файла.

import pandas as pd
def data_shape(x):
    data = pd.read_csv(x)
    return data.shape
